# %%
import pandas as pd

# %%
df = pd.read_csv('flights_sbrf_to_sbsp.csv')

# %%
df
# Out:
#         ANO  MES EMPRESA ORIGEM DESTINO  TARIFA  ASSENTOS
# 0      2017    8     AZU   SBRF    SBSP   630,9         1
# 1      2017    8     AZU   SBRF    SBSP  937,46         1
# 2      2017    8     AZU   SBRF    SBSP  690,71         1
# 3      2017    8     AZU   SBRF    SBSP  319,51         1
# 4      2017    8     AZU   SBRF    SBSP   399,4         2
# ...     ...  ...     ...    ...     ...     ...       ...
# 41167  2022    7     TAM   SBRF    SBSP  857,07         1
# 41168  2022    7     TAM   SBRF    SBSP    584,         1
# 41169  2022    7     TAM   SBRF    SBSP  1124,9         2
# 41170  2022    7     TAM   SBRF    SBSP    961,         1
# 41171  2022    7     TAM   SBRF    SBSP  1049,9         2
#
# [41172 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# ANO         0
# MES         0
# EMPRESA     0
# ORIGEM      0
# DESTINO     0
# TARIFA      0
# ASSENTOS    0
# dtype: int64

# %%
df.dtypes
# Out:
# ANO          int64
# MES          int64
# EMPRESA     object
# ORIGEM      object
# DESTINO     object
# TARIFA      object
# ASSENTOS     int64
# dtype: object

# %%
tarifas = df['TARIFA']
for i in range(len(tarifas)):
    df['TARIFA'][i] = df['TARIFA'][i].replace(',','.')
df
# Out:
# C:\Users\pedro\AppData\Local\Temp\ipykernel_24116\1260594942.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TARIFA'][i] = df['TARIFA'][i].replace(',','.')
#         ANO  MES EMPRESA ORIGEM DESTINO  TARIFA  ASSENTOS
# 0      2017    8     AZU   SBRF    SBSP   630.9         1
# 1      2017    8     AZU   SBRF    SBSP  937.46         1
# 2      2017    8     AZU   SBRF    SBSP  690.71         1
# 3      2017    8     AZU   SBRF    SBSP  319.51         1
# 4      2017    8     AZU   SBRF    SBSP   399.4         2
# ...     ...  ...     ...    ...     ...     ...       ...
# 41167  2022    7     TAM   SBRF    SBSP  857.07         1
# 41168  2022    7     TAM   SBRF    SBSP    584.         1
# 41169  2022    7     TAM   SBRF    SBSP  1124.9         2
# ...

# %%
df.TARIFA = df.TARIFA.astype(float)
print(df.dtypes)
# Out:
# ANO           int64
# MES           int64
# EMPRESA      object
# ORIGEM       object
# DESTINO      object
# TARIFA      float64
# ASSENTOS      int64
# dtype: object

# %%
df.rename(columns={'ANO':'ano','MES':'mes','EMPRESA':'empresa','ORIGEM':'origem','DESTINO':'destino','TARIFA':'tarifa','ASSENTOS':'assentos'}, inplace=True)
df
# Out:
#         ano  mes empresa origem destino   tarifa  assentos
# 0      2017    8     AZU   SBRF    SBSP   630.90         1
# 1      2017    8     AZU   SBRF    SBSP   937.46         1
# 2      2017    8     AZU   SBRF    SBSP   690.71         1
# 3      2017    8     AZU   SBRF    SBSP   319.51         1
# 4      2017    8     AZU   SBRF    SBSP   399.40         2
# ...     ...  ...     ...    ...     ...      ...       ...
# 41167  2022    7     TAM   SBRF    SBSP   857.07         1
# 41168  2022    7     TAM   SBRF    SBSP   584.00         1
# 41169  2022    7     TAM   SBRF    SBSP  1124.90         2
# 41170  2022    7     TAM   SBRF    SBSP   961.00         1
# 41171  2022    7     TAM   SBRF    SBSP  1049.90         2
#
# [41172 rows x 7 columns]

# %%
df['data'] = ''
for i in range(len(df)):
    if df['mes'][i] < 10:
        df['data'][i] = f"{df['ano'][i]}-0{df['mes'][i]}-01"
    else:
        df['data'][i] = f"{df['ano'][i]}-{df['mes'][i]}-01"
# Out:
# C:\Users\pedro\AppData\Local\Temp\ipykernel_24116\1915777913.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['data'][i] = f"{df['ano'][i]}-0{df['mes'][i]}-01"
# C:\Users\pedro\AppData\Local\Temp\ipykernel_24116\1915777913.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['data'][i] = f"{df['ano'][i]}-{df['mes'][i]}-01"

# %%
df['data'] = pd.to_datetime(df['data'])
print(df.dtypes)
# Out:
# ano                  int64
# mes                  int64
# empresa             object
# origem              object
# destino             object
# tarifa             float64
# assentos             int64
# data        datetime64[ns]
# dtype: object

# %%
df
# Out:
#         ano  mes empresa origem destino   tarifa  assentos       data
# 0      2017    8     AZU   SBRF    SBSP   630.90         1 2017-08-01
# 1      2017    8     AZU   SBRF    SBSP   937.46         1 2017-08-01
# 2      2017    8     AZU   SBRF    SBSP   690.71         1 2017-08-01
# 3      2017    8     AZU   SBRF    SBSP   319.51         1 2017-08-01
# 4      2017    8     AZU   SBRF    SBSP   399.40         2 2017-08-01
# ...     ...  ...     ...    ...     ...      ...       ...        ...
# 41167  2022    7     TAM   SBRF    SBSP   857.07         1 2022-07-01
# 41168  2022    7     TAM   SBRF    SBSP   584.00         1 2022-07-01
# 41169  2022    7     TAM   SBRF    SBSP  1124.90         2 2022-07-01
# 41170  2022    7     TAM   SBRF    SBSP   961.00         1 2022-07-01
# 41171  2022    7     TAM   SBRF    SBSP  1049.90         2 2022-07-01
#
# [41172 rows x 8 columns]

# %%
df_mes = df.groupby('data').sum()

# %%
df_mes.drop(['ano','mes'], axis=1, inplace=True)
# Out:
#                 tarifa  assentos
# data
# 2017-08-01   174720.60      8900
# 2017-09-01   239323.95      9015
# 2017-10-01   262390.54      9496
# 2017-11-01   206055.28      9575
# 2017-12-01   179468.00      7016
# 2018-01-01   282289.49      9853
# 2018-02-01   161638.84     11506
# 2018-03-01   229455.09     11505
# 2018-04-01   243052.82     13320
# 2018-05-01   281544.79     12355
# 2018-06-01   239180.87     12047
# 2018-07-01   363095.25     11242
# 2018-08-01   343861.91     11567
# 2018-09-01   240906.43      7832
# 2018-10-01   346703.15      7542
# 2018-11-01   378393.00     12775
# 2018-12-01   253211.80      6885
# 2019-01-01   384562.11     10844
# 2019-02-01   309541.98      7582
# 2019-03-01   219307.38      9076
# 2019-04-01   210738.60      6029
# 2019-05-01   139193.49      5100
# 2019-06-01   162710.93      5518
# 2019-07-01   274409.95      8498
# 2019-08-01   342485.30      8830
# 2019-09-01   301684.17      7183
# 2019-10-01   304931.84      6909
# ...

# %%
df_mes['tarifaporassento'] = ''
for c in range(len(df_mes)):
    df_mes['tarifaporassento'][c] = df_mes['tarifa'][c]/df_mes['assentos'][c]
df_mes['tarifaporassento'] = pd.to_numeric(df_mes['tarifaporassento'])
round(df_mes["tarifaporassento"], 2)
df_mes
# Out:
# C:\Users\pedro\AppData\Local\Temp\ipykernel_24116\93597081.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mes['tarifaporassento'][c] = df_mes['tarifa'][c]/df_mes['assentos'][c]
#                 tarifa  assentos  tarifaporassento
# data
# 2017-08-01   174720.60      8900         19.631528
# 2017-09-01   239323.95      9015         26.547304
# 2017-10-01   262390.54      9496         27.631691
# 2017-11-01   206055.28      9575         21.520134
# 2017-12-01   179468.00      7016         25.579818
# 2018-01-01   282289.49      9853         28.650106
# 2018-02-01   161638.84     11506         14.048222
# 2018-03-01   229455.09     11505         19.943945
# 2018-04-01   243052.82     13320         18.247209
# 2018-05-01   281544.79     12355         22.787923
# ...

# %%
df['assentos'].describe()
# Out:
# count    41172.000000
# mean        15.294108
# std         55.193038
# min          1.000000
# 25%          1.000000
# 50%          3.000000
# 75%          8.000000
# max       1855.000000
# Name: assentos, dtype: float64
